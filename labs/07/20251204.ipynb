# %%
def listenausschreiber (list):
    if list == []:
        print('Deine Liste ist leer!')
    ausgeschrieben=' '.join(list)
    print(ausgeschrieben)
spam = ['apples', 'bananas', 'tofu', 'cats']
leere = []

listenausschreiber(spam)
listenausschreiber(leere)
# Out:
# apples bananas tofu cats
# Deine Liste ist leer!

# %%
import random
numberOfStreaks = 0
for k in range (200):
    experimentlist=[]
    for i in range(6):
# Code that creates a list of 100 'heads' or 'tails' values.
        toss=random.randint(1,2)
        experimentlist.append(toss)
# Code that checks if there is a streak of 6 heads or tails in a row.
    if len(set(experimentlist)) == 1:
        numberOfStreaks = (numberOfStreaks+1)
    print(experimentlist)
    print(k, numberOfStreaks)
#print('Chance of streak: %s%%' % (numberOfStreaks / 100))
# Out:
# [1, 1, 2, 2, 1, 2]
# 0 0
# [1, 2, 2, 1, 1, 1]
# 1 0
# [1, 1, 1, 1, 1, 2]
# 2 0
# [2, 2, 1, 1, 1, 2]
# 3 0
# [2, 2, 1, 2, 1, 2]
# 4 0
# [2, 2, 2, 1, 1, 1]
# 5 0
# [2, 1, 1, 1, 1, 1]
# 6 0
# [2, 2, 1, 1, 2, 2]
# 7 0
# [1, 2, 1, 1, 2, 2]
# 8 0
# [2, 2, 2, 1, 1, 2]
# 9 0
# [2, 2, 1, 1, 1, 2]
# 10 0
# [2, 1, 1, 2, 1, 2]
# 11 0
# [2, 2, 1, 1, 2, 2]
# 12 0
# [2, 1, 2, 1, 2, 1]
# 13 0
# [1, 1, 1, 1, 1, 2]
# 14 0
# [2, 1, 1, 1, 1, 1]
# 15 0
# [2, 2, 2, 1, 1, 2]
# 16 0
# [1, 2, 1, 2, 1, 1]
# 17 0
# [1, 1, 1, 1, 1, 1]
# 18 1
# [2, 2, 2, 1, 1, 2]
# 19 1
# [2, 2, 2, 2, 2, 2]
# 20 2
# [1, 2, 1, 1, 2, 1]
# 21 2
# [2, 1, 1, 2, 2, 1]
# 22 2
# [2, 1, 2, 1, 1, 1]
# 23 2
# [2, 1, 1, 1, 1, 1]
# 24 2
# [1, 2, 2, 2, 2, 1]
# 25 2
# [2, 2, 2, 1, 1, 1]
# 26 2
# [2, 2, 1, 2, 1, 1]
# 27 2
# [1, 1, 1, 2, 2, 1]
# 28 2
# [1, 1, 1, 2, 1, 2]
# 29 2
# [1, 1, 1, 1, 1, 2]
# 30 2
# [2, 1, 2, 1, 2, 2]
# 31 2
# [1, 2, 1, 1, 1, 2]
# 32 2
# [2, 1, 1, 1, 1, 2]
# 33 2
# [2, 2, 1, 2, 2, 1]
# 34 2
# [1, 2, 2, 2, 2, 2]
# 35 2
# ...
